# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
df = pd.read_csv('data archive/data_processed_with_coordinates.csv')
df['bds'] = df['bds'].replace("Studio", 0).astype(int)
features = df[['bds', 'lat', 'lng']]
target = df['cost']
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2,shuffle = True)

# %%
gb_model = GradientBoostingRegressor()
rf_model = RandomForestRegressor()
knn_model = KNeighborsRegressor()
svr_model = SVR()
linear_model = LinearRegression()
model_list = {"Gradient Boosting" : gb_model, "Random Forest": rf_model, "K Neighbors": knn_model, "Support Vector Machine": svr_model, 
              "Linear Regrression": linear_model}

# %%
for  model_name, model in model_list.items():
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    rms = np.sqrt(mean_squared_error(y_test, predictions))
    error_percentage = (((predictions - y_test) / y_test) * 100).mean()
    print(f"{model_name}\nRoot mean squared error: {rms}\nError Percentage: {error_percentage}\n{"_"*50}")
# Out:
# Gradient Boosting
# Root mean squared error: 1649.6724593892075
# Error Percentage: 2.7157443689132235
# __________________________________________________
# Random Forest
# Root mean squared error: 1641.1332811898762
# Error Percentage: 2.1137696396331784
# __________________________________________________
# K Neighbors
# Root mean squared error: 1757.190930575197
# Error Percentage: 4.104066276570976
# __________________________________________________
# Support Vector Machine
# Root mean squared error: 2310.5166159962096
# Error Percentage: -1.676647954507068
# __________________________________________________
# Linear Regrression
# Root mean squared error: 1899.9959310880788
# Error Percentage: 4.705848717016604
# __________________________________________________

# %%
model = Sequential([
    Dense(64, input_dim=3, activation='relu'),  
    Dense(32, activation='relu'),               
    Dense(1)                                    
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
model.fit(X_train, y_train, epochs=200, batch_size=16, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/200
# C:\Users\T T Ajith Kumar\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 18066046.0000 - val_loss: 16697252.0000
# Epoch 2/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17971208.0000 - val_loss: 15586053.0000
# Epoch 3/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19315248.0000 - val_loss: 13131118.0000
# Epoch 4/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12919387.0000 - val_loss: 9199209.0000
# Epoch 5/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9594684.0000 - val_loss: 4998473.0000
# Epoch 6/200
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5956942.5000 - val_loss: 2445780.7500
# Epoch 7/200
# ...

# %%
predictions = model.predict(X_test)
rms = np.sqrt(mean_squared_error(y_test, predictions))
rms
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# np.float64(1231.7101278537946)

# %%
from xgboost import XGBRegressor
est = [20*i for i in range(12,25)]
#depth = [i for i in range(3,10)]
depth = [6]
l=[]
for i in est:
    for j in depth:
        xgb_model = XGBRegressor(n_estimators=i, learning_rate=0.1, max_depth=j)
        xgb_model.fit(X_train, y_train)
        predictions = xgb_model.predict(X_test)
        rms = np.sqrt(mean_squared_error(y_test, predictions))
        l.append([i,j,rms])

# %%
l_sorted = sorted(l, key=lambda x: x[2])
l_sorted
# Out:
# [[460, 6, np.float64(785.4785784379044)],
#  [440, 6, np.float64(785.9283635127742)],
#  [480, 6, np.float64(786.0823507595404)],
#  [380, 6, np.float64(786.1776272284136)],
#  [400, 6, np.float64(786.3711391588081)],
#  [340, 6, np.float64(786.3899613639937)],
#  [420, 6, np.float64(786.5635625925639)],
#  [360, 6, np.float64(786.628882908624)],
#  [320, 6, np.float64(786.6420510890971)],
#  [300, 6, np.float64(786.6986931564677)],
#  [280, 6, np.float64(787.6616486344373)],
#  [260, 6, np.float64(787.8872841038818)],
#  [240, 6, np.float64(788.0834938266469)]]

# %%
xgb_model = XGBRegressor(n_estimators=450, learning_rate=0.1, max_depth=6)
xgb_model.fit(X_train, y_train)
predictions = xgb_model.predict(X_test)
rms = np.sqrt(mean_squared_error(y_test, predictions))
rms
# Out:
# np.float64(785.6901433249503)

# %%
gb_model_final = GradientBoostingRegressor()
gb_model_final.fit(X_train, y_train)
predictions = gb_model_final.predict(X_test)
rms = np.sqrt(mean_squared_error(y_test, predictions))
error_percentage = (((predictions - y_test) / y_test) * 100).mean()
print(f"Root mean squared error: {rms}\nError Percentage: {error_percentage}")
# Out:
# Root mean squared error: 867.1423946345316
# Error Percentage: 4.6882085663706246

# %%
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
with open('model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)
predictions = gb_model_final.predict(X_test)
rms = np.sqrt(mean_squared_error(y_test, predictions))
rms
# Out:
# np.float64(867.1423946345316)
